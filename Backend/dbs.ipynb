# %% [markdown]
# ## create database

# %%
from sqlalchemy import Column, Integer, String, Text, Numeric, DateTime, Index
from sqlalchemy.orm import declarative_base
from datetime import datetime

Base = declarative_base()

class Document(Base):
    __tablename__ = 'documents'

    id = Column(Integer, primary_key=True, index=True)
    vendor = Column(String(100), index=True)
    data = Column(Text)
    amount = Column(Numeric(12, 2), index=True)
    category = Column(String(50), index=True)
    created_at = Column(DateTime, default=datetime.utcnow)

    __table_args__ = (
        Index('idx_vendor_category', 'vendor', 'category'),
    )

# %% [markdown]
# ## connect database

# %%
from sqlalchemy import create_engine


# Local SQLite database file
DATABASE_URL = "sqlite:///./local_documents.db"

engine = create_engine(DATABASE_URL, echo=True)
Base.metadata.create_all(bind=engine)

print("✅ Local SQLite database and tables created successfully.")
# Out:
# 2025-07-21 20:42:04,484 INFO sqlalchemy.engine.Engine BEGIN (implicit)
# 2025-07-21 20:42:04,486 INFO sqlalchemy.engine.Engine PRAGMA main.table_info("documents")
# 2025-07-21 20:42:04,487 INFO sqlalchemy.engine.Engine [raw sql] ()
# 2025-07-21 20:42:04,489 INFO sqlalchemy.engine.Engine COMMIT
# ✅ Local SQLite database and tables created successfully.

# %% [markdown]
# ## insert database

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
# from models import Document
from datetime import datetime

DATABASE_URL = "sqlite:///./local_documents.db"
engine = create_engine(DATABASE_URL)
SessionLocal = sessionmaker(bind=engine)

session = SessionLocal()

# Insert a sample document
new_doc = Document(
    vendor="Apple",
    data="Invoice data for MacBook",
    amount=159999.99,
    category="Computers",
    created_at=datetime.utcnow()
)

session.add(new_doc)
session.commit()
session.refresh(new_doc)

print(f"✅ Inserted Document ID: {new_doc.id}")
session.close()
# Out:
# ✅ Inserted Document ID: 1003

# %%
from sqlalchemy import create_engine
from sqlalchemy.orm import sessionmaker
from datetime import datetime, timedelta
import random
import string

# Assuming your Document model is already defined
# from models import Document

# Setup DB
DATABASE_URL = "sqlite:///./local_documents.db"
engine = create_engine(DATABASE_URL)
SessionLocal = sessionmaker(bind=engine)
session = SessionLocal()

# Sample data for randomization
vendors = ["Apple", "Microsoft", "Amazon", "Google", "Samsung", "Sony", "Lenovo", "Dell"]
categories = ["Computers", "Utilities", "Electricity", "Internet", "Software", "Accessories"]

def random_string(length=20):
    return ''.join(random.choices(string.ascii_letters + string.digits, k=length))

def random_date():
    # Generate a random date within the past 2 years
    days_ago = random.randint(0, 730)
    return datetime.utcnow() - timedelta(days=days_ago)

documents = []

for _ in range(1000):
    doc = Document(
        vendor=random.choice(vendors),
        data=f"Invoice data for {random_string(10)}",
        amount=round(random.uniform(50, 10000), 2),
        category=random.choice(categories),
        created_at=random_date()
    )
    documents.append(doc)

# Bulk insert
session.bulk_save_objects(documents)
session.commit()
print("✅ Inserted 1000 random sample documents")
session.close()
# Out:
# ✅ Inserted 1000 random sample documents

# %%
def get_all_documents():
    session = SessionLocal()
    try:
        documents = session.query(Document).all()
        result = []
        for doc in documents:
            result.append({
                "id": doc.id,
                "vendor": doc.vendor,
                "data": doc.data,
                "amount": float(doc.amount),
                "category": doc.category,
                "created_at": doc.created_at.isoformat()
            })
        return result
    except Exception as e:
        print("❌ Error retrieving documents:", e)
        return []
    finally:
        session.close()

# %%
get_all_documents()
# Out:
# [{'id': 1,
#   'vendor': 'Google',
#   'data': 'Invoice data for 4azX5DZa2B',
#   'amount': 3849.86,
#   'category': 'Computers',
#   'created_at': '2024-06-26T09:55:33.619896'},
#  {'id': 2,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 3S39BktxxI',
#   'amount': 2279.34,
#   'category': 'Accessories',
#   'created_at': '2024-03-03T09:55:33.619896'},
#  {'id': 3,
#   'vendor': 'Sony',
#   'data': 'Invoice data for SjhhWtDMLc',
#   'amount': 8448.37,
#   'category': 'Accessories',
#   'created_at': '2023-08-07T09:55:33.619896'},
#  {'id': 4,
#   'vendor': 'Apple',
#   'data': 'Invoice data for Om9k5mT33T',
#   'amount': 3443.61,
#   'category': 'Software',
#   'created_at': '2023-12-09T09:55:33.619896'},
#  {'id': 5,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for eZ3t54l0c5',
#   'amount': 482.46,
#   'category': 'Computers',
#   'created_at': '2024-11-08T09:55:33.619896'},
#  {'id': 6,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for 54g7YuZEFM',
#   'amount': 8214.13,
#   'category': 'Software',
#   'created_at': '2024-04-09T09:55:33.620896'},
#  {'id': 7,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for 8Ag3PjdBmn',
#   'amount': 976.18,
#   'category': 'Computers',
#   'created_at': '2024-07-01T09:55:33.620896'},
#  {'id': 8,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for Kmtv2Rl7HG',
#   'amount': 7767.44,
#   'category': 'Utilities',
#   'created_at': '2025-04-16T09:55:33.620896'},
#  {'id': 9,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 6vOee6LiXt',
#   'amount': 1786.47,
#   'category': 'Software',
#   'created_at': '2023-09-02T09:55:33.620896'},
#  {'id': 10,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for ZooBTCPBFc',
#   'amount': 9476.72,
#   'category': 'Utilities',
#   'created_at': '2024-12-05T09:55:33.620896'},
#  {'id': 11,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for qcjV1nYDji',
#   'amount': 994.95,
#   'category': 'Internet',
#   'created_at': '2025-05-02T09:55:33.620896'},
#  {'id': 12,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for Huue91lZH1',
#   'amount': 4929.48,
#   'category': 'Utilities',
#   'created_at': '2023-09-20T09:55:33.620896'},
#  {'id': 13,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for yRoN07EpuX',
#   'amount': 8476.7,
#   'category': 'Electricity',
#   'created_at': '2025-03-28T09:55:33.620896'},
#  {'id': 14,
#   'vendor': 'Sony',
#   'data': 'Invoice data for nrv17obX9e',
#   'amount': 243.23,
#   'category': 'Internet',
#   'created_at': '2023-09-13T09:55:33.620896'},
#  {'id': 15,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for vAWutMAhhd',
#   'amount': 3498.21,
#   'category': 'Accessories',
#   'created_at': '2024-05-08T09:55:33.620896'},
#  {'id': 16,
#   'vendor': 'Google',
#   'data': 'Invoice data for uKwvgqIo70',
#   'amount': 8999.54,
#   'category': 'Utilities',
#   'created_at': '2024-08-17T09:55:33.620896'},
#  {'id': 17,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for VGgI0H6Hii',
#   'amount': 2102.97,
#   'category': 'Internet',
#   'created_at': '2024-04-04T09:55:33.620896'},
#  {'id': 18,
#   'vendor': 'Dell',
#   'data': 'Invoice data for JQqKlviQof',
#   'amount': 775.4,
#   'category': 'Utilities',
#   'created_at': '2023-12-16T09:55:33.620896'},
#  {'id': 19,
#   'vendor': 'Google',
#   'data': 'Invoice data for 90yNH9PHgQ',
#   'amount': 556.98,
#   'category': 'Accessories',
#   'created_at': '2025-05-17T09:55:33.620896'},
#  {'id': 20,
#   'vendor': 'Google',
#   'data': 'Invoice data for byX4iU06Jg',
#   'amount': 7946.41,
#   'category': 'Internet',
#   'created_at': '2025-02-21T09:55:33.620896'},
#  {'id': 21,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 7UvZ5KJOjE',
#   'amount': 9795.43,
#   'category': 'Software',
#   'created_at': '2024-09-09T09:55:33.620896'},
#  {'id': 22,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for M9zwLfirxa',
#   'amount': 1551.06,
#   'category': 'Computers',
#   'created_at': '2024-04-13T09:55:33.620896'},
#  {'id': 23,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for FkZxP2qZic',
#   'amount': 5763.38,
#   'category': 'Utilities',
#   'created_at': '2024-06-18T09:55:33.620896'},
#  {'id': 24,
#   'vendor': 'Apple',
#   'data': 'Invoice data for qD7jQbrKiC',
#   'amount': 6422.25,
#   'category': 'Internet',
#   'created_at': '2024-08-21T09:55:33.620896'},
#  {'id': 25,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for NqCzSYsR9J',
#   'amount': 7184.15,
#   'category': 'Accessories',
#   'created_at': '2025-01-27T09:55:33.620896'},
#  {'id': 26,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for 580dsD2p2M',
#   'amount': 3255.59,
#   'category': 'Computers',
#   'created_at': '2024-09-09T09:55:33.621916'},
#  {'id': 27,
#   'vendor': 'Sony',
#   'data': 'Invoice data for EUHPqMHsgu',
#   'amount': 9122.4,
#   'category': 'Internet',
#   'created_at': '2025-06-28T09:55:33.621916'},
#  {'id': 28,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for y88SnyztKi',
#   'amount': 3341.52,
#   'category': 'Utilities',
#   'created_at': '2024-06-15T09:55:33.621916'},
#  {'id': 29,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for tXgggxWDHl',
#   'amount': 5811.07,
#   'category': 'Utilities',
#   'created_at': '2025-01-10T09:55:33.621916'},
#  {'id': 30,
#   'vendor': 'Google',
#   'data': 'Invoice data for bJcDueAbZc',
#   'amount': 2731.62,
#   'category': 'Internet',
#   'created_at': '2023-12-25T09:55:33.621916'},
#  {'id': 31,
#   'vendor': 'Apple',
#   'data': 'Invoice data for nmoviTGlC4',
#   'amount': 6417.89,
#   'category': 'Utilities',
#   'created_at': '2024-11-01T09:55:33.621916'},
#  {'id': 32,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for 9o4PrNZgFZ',
#   'amount': 1970.77,
#   'category': 'Internet',
#   'created_at': '2025-01-16T09:55:33.621916'},
#  {'id': 33,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for r6tgGolQTg',
#   'amount': 4173.92,
#   'category': 'Computers',
#   'created_at': '2024-12-18T09:55:33.621916'},
#  {'id': 34,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for j7YcX0RO1G',
#   'amount': 5649.55,
#   'category': 'Electricity',
#   'created_at': '2025-04-30T09:55:33.621916'},
#  {'id': 35,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for vhDbPDkvox',
#   'amount': 5696.6,
#   'category': 'Accessories',
#   'created_at': '2025-04-26T09:55:33.621916'},
#  {'id': 36,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for 5byw7SHUX5',
#   'amount': 465.82,
#   'category': 'Internet',
#   'created_at': '2025-01-29T09:55:33.621916'},
#  {'id': 37,
#   'vendor': 'Sony',
#   'data': 'Invoice data for yXBYcD7s0K',
#   'amount': 1888.83,
#   'category': 'Internet',
#   'created_at': '2023-08-02T09:55:33.621916'},
#  {'id': 38,
#   'vendor': 'Apple',
#   'data': 'Invoice data for tS1Cr5GkUN',
#   'amount': 8359.9,
#   'category': 'Computers',
#   'created_at': '2023-10-02T09:55:33.621916'},
#  {'id': 39,
#   'vendor': 'Apple',
#   'data': 'Invoice data for ZiJUVVbeg9',
#   'amount': 6289.9,
#   'category': 'Internet',
#   'created_at': '2025-04-03T09:55:33.621916'},
#  {'id': 40,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for IU7ihNRryq',
#   'amount': 5911.6,
#   'category': 'Utilities',
#   'created_at': '2024-01-31T09:55:33.621916'},
#  {'id': 41,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for WU3IZosmtU',
#   'amount': 441.59,
#   'category': 'Internet',
#   'created_at': '2024-11-04T09:55:33.621916'},
#  {'id': 42,
#   'vendor': 'Dell',
#   'data': 'Invoice data for herA1H2NJa',
#   'amount': 6738.75,
#   'category': 'Internet',
#   'created_at': '2023-09-18T09:55:33.621916'},
#  {'id': 43,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for QLCnBFAfUo',
#   'amount': 4697.07,
#   'category': 'Computers',
#   'created_at': '2024-05-04T09:55:33.621916'},
#  {'id': 44,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for VNxNJo80iH',
#   'amount': 8921.12,
#   'category': 'Software',
#   'created_at': '2024-11-27T09:55:33.621916'},
#  {'id': 45,
#   'vendor': 'Sony',
#   'data': 'Invoice data for gOi3kRVSku',
#   'amount': 6473.91,
#   'category': 'Utilities',
#   'created_at': '2024-09-10T09:55:33.621916'},
#  {'id': 46,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for IsWgPTZiLV',
#   'amount': 1248.23,
#   'category': 'Accessories',
#   'created_at': '2024-02-27T09:55:33.621916'},
#  {'id': 47,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for 51OX5ooHFK',
#   'amount': 9414.54,
#   'category': 'Electricity',
#   'created_at': '2024-02-09T09:55:33.621916'},
#  {'id': 48,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for aWWkSysjST',
#   'amount': 1657.55,
#   'category': 'Electricity',
#   'created_at': '2023-08-16T09:55:33.622900'},
#  {'id': 49,
#   'vendor': 'Apple',
#   'data': 'Invoice data for PX0etEhljO',
#   'amount': 6134.09,
#   'category': 'Electricity',
#   'created_at': '2024-01-09T09:55:33.622900'},
#  {'id': 50,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for HXjjqTjiJ3',
#   'amount': 6849.85,
#   'category': 'Software',
#   'created_at': '2024-03-23T09:55:33.622900'},
#  {'id': 51,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for NRd7l6ZafX',
#   'amount': 5367.97,
#   'category': 'Internet',
#   'created_at': '2025-03-05T09:55:33.622900'},
#  {'id': 52,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for jKPp84ymOm',
#   'amount': 2509.42,
#   'category': 'Software',
#   'created_at': '2023-12-18T09:55:33.622900'},
#  {'id': 53,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for o591quv0ml',
#   'amount': 8359.61,
#   'category': 'Software',
#   'created_at': '2025-04-14T09:55:33.622900'},
#  {'id': 54,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for DQegsB6KqL',
#   'amount': 1259.39,
#   'category': 'Utilities',
#   'created_at': '2023-09-17T09:55:33.622900'},
#  {'id': 55,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for WT4KejkBGO',
#   'amount': 5096.26,
#   'category': 'Software',
#   'created_at': '2025-02-01T09:55:33.622900'},
#  {'id': 56,
#   'vendor': 'Dell',
#   'data': 'Invoice data for 7jNZSYAhrj',
#   'amount': 6929.34,
#   'category': 'Internet',
#   'created_at': '2023-10-16T09:55:33.622900'},
#  {'id': 57,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for NTi9WG2RJQ',
#   'amount': 5716.8,
#   'category': 'Electricity',
#   'created_at': '2023-07-29T09:55:33.622900'},
#  {'id': 58,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for 2LRy3DtwuM',
#   'amount': 5484.77,
#   'category': 'Accessories',
#   'created_at': '2025-01-04T09:55:33.622900'},
#  {'id': 59,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 9umIUbqQ18',
#   'amount': 6879.84,
#   'category': 'Accessories',
#   'created_at': '2023-08-06T09:55:33.622900'},
#  {'id': 60,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for 8Tss1vhU5I',
#   'amount': 7962.24,
#   'category': 'Utilities',
#   'created_at': '2023-10-13T09:55:33.622900'},
#  {'id': 61,
#   'vendor': 'Apple',
#   'data': 'Invoice data for NvlDftRdgr',
#   'amount': 7107.47,
#   'category': 'Computers',
#   'created_at': '2024-11-11T09:55:33.622900'},
#  {'id': 62,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for fr1eEUDByi',
#   'amount': 3461.6,
#   'category': 'Software',
#   'created_at': '2024-05-13T09:55:33.622900'},
#  {'id': 63,
#   'vendor': 'Sony',
#   'data': 'Invoice data for r4iPb4BaYb',
#   'amount': 4321.43,
#   'category': 'Electricity',
#   'created_at': '2024-06-11T09:55:33.622900'},
#  {'id': 64,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for WRBmwMVckM',
#   'amount': 8678.2,
#   'category': 'Internet',
#   'created_at': '2024-01-23T09:55:33.622900'},
#  {'id': 65,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for xmT86CSITO',
#   'amount': 7404.3,
#   'category': 'Electricity',
#   'created_at': '2024-09-02T09:55:33.622900'},
#  {'id': 66,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for Y4ndhGNZNP',
#   'amount': 5483.55,
#   'category': 'Computers',
#   'created_at': '2024-04-30T09:55:33.622900'},
#  {'id': 67,
#   'vendor': 'Google',
#   'data': 'Invoice data for DQJHqmq7rE',
#   'amount': 3987.95,
#   'category': 'Utilities',
#   'created_at': '2025-01-31T09:55:33.623895'},
#  {'id': 68,
#   'vendor': 'Dell',
#   'data': 'Invoice data for NVO9HEZAkR',
#   'amount': 3619.86,
#   'category': 'Utilities',
#   'created_at': '2024-02-22T09:55:33.623895'},
#  {'id': 69,
#   'vendor': 'Sony',
#   'data': 'Invoice data for bRiUYuhply',
#   'amount': 1836.55,
#   'category': 'Internet',
#   'created_at': '2025-01-06T09:55:33.623895'},
#  {'id': 70,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for cubmbxqn4Q',
#   'amount': 3287.49,
#   'category': 'Utilities',
#   'created_at': '2024-02-27T09:55:33.623895'},
#  {'id': 71,
#   'vendor': 'Dell',
#   'data': 'Invoice data for NtZk6PxAHb',
#   'amount': 4094.51,
#   'category': 'Internet',
#   'created_at': '2024-03-27T09:55:33.623895'},
#  {'id': 72,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for 4qh5rd1Tfj',
#   'amount': 6844.17,
#   'category': 'Computers',
#   'created_at': '2024-09-21T09:55:33.623895'},
#  {'id': 73,
#   'vendor': 'Apple',
#   'data': 'Invoice data for OIwqPqaTH4',
#   'amount': 9542.11,
#   'category': 'Internet',
#   'created_at': '2024-02-01T09:55:33.623895'},
#  {'id': 74,
#   'vendor': 'Apple',
#   'data': 'Invoice data for vFIDTnLx7w',
#   'amount': 9537.18,
#   'category': 'Accessories',
#   'created_at': '2023-09-10T09:55:33.623895'},
#  {'id': 75,
#   'vendor': 'Dell',
#   'data': 'Invoice data for sDQ0YwNCUH',
#   'amount': 9750.34,
#   'category': 'Utilities',
#   'created_at': '2024-01-20T09:55:33.623895'},
#  {'id': 76,
#   'vendor': 'Apple',
#   'data': 'Invoice data for 8JD9xy1Eeq',
#   'amount': 6591.13,
#   'category': 'Electricity',
#   'created_at': '2023-11-27T09:55:33.623895'},
#  {'id': 77,
#   'vendor': 'Dell',
#   'data': 'Invoice data for e4Q4ty29mJ',
#   'amount': 1968.05,
#   'category': 'Accessories',
#   'created_at': '2024-12-11T09:55:33.623895'},
#  {'id': 78,
#   'vendor': 'Apple',
#   'data': 'Invoice data for n6DzdulhgF',
#   'amount': 6343.88,
#   'category': 'Accessories',
#   'created_at': '2024-04-21T09:55:33.623895'},
#  {'id': 79,
#   'vendor': 'Sony',
#   'data': 'Invoice data for rTpwYRMN51',
#   'amount': 5408.77,
#   'category': 'Electricity',
#   'created_at': '2024-03-05T09:55:33.623895'},
#  {'id': 80,
#   'vendor': 'Sony',
#   'data': 'Invoice data for JGDJijyZCs',
#   'amount': 8770.35,
#   'category': 'Computers',
#   'created_at': '2025-02-14T09:55:33.623895'},
#  {'id': 81,
#   'vendor': 'Dell',
#   'data': 'Invoice data for QAXP8Qa6Lj',
#   'amount': 129.96,
#   'category': 'Computers',
#   'created_at': '2025-07-02T09:55:33.623895'},
#  {'id': 82,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 66ggUB9zVH',
#   'amount': 5740.97,
#   'category': 'Internet',
#   'created_at': '2023-09-30T09:55:33.623895'},
#  {'id': 83,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for ZAQmpR2hHF',
#   'amount': 7827.56,
#   'category': 'Electricity',
#   'created_at': '2024-11-23T09:55:33.623895'},
#  {'id': 84,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for k6qyGRzmRa',
#   'amount': 2068.42,
#   'category': 'Utilities',
#   'created_at': '2023-12-23T09:55:33.623895'},
#  {'id': 85,
#   'vendor': 'Google',
#   'data': 'Invoice data for 5wiiwPeiQP',
#   'amount': 8688.09,
#   'category': 'Internet',
#   'created_at': '2025-03-26T09:55:33.623895'},
#  {'id': 86,
#   'vendor': 'Sony',
#   'data': 'Invoice data for sxErwxwpIF',
#   'amount': 2416.34,
#   'category': 'Accessories',
#   'created_at': '2024-04-03T09:55:33.623895'},
#  {'id': 87,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for RwupOE7F1q',
#   'amount': 7371.69,
#   'category': 'Computers',
#   'created_at': '2024-03-07T09:55:33.624895'},
#  {'id': 88,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for 1wKyIQuUrU',
#   'amount': 1614.97,
#   'category': 'Electricity',
#   'created_at': '2024-10-12T09:55:33.624895'},
#  {'id': 89,
#   'vendor': 'Dell',
#   'data': 'Invoice data for PGlp6I7S59',
#   'amount': 1273.98,
#   'category': 'Software',
#   'created_at': '2024-03-12T09:55:33.624895'},
#  {'id': 90,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for xOLpNWO9yw',
#   'amount': 8868.35,
#   'category': 'Software',
#   'created_at': '2024-05-12T09:55:33.624895'},
#  {'id': 91,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for HcxXxhB6GZ',
#   'amount': 6327.85,
#   'category': 'Electricity',
#   'created_at': '2023-09-22T09:55:33.624895'},
#  {'id': 92,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for 9Y62ezfA2L',
#   'amount': 8080.39,
#   'category': 'Software',
#   'created_at': '2024-04-09T09:55:33.624895'},
#  {'id': 93,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for VrADNdoNVZ',
#   'amount': 4168.47,
#   'category': 'Internet',
#   'created_at': '2024-10-23T09:55:33.624895'},
#  {'id': 94,
#   'vendor': 'Google',
#   'data': 'Invoice data for jku4PwEXcH',
#   'amount': 3931.63,
#   'category': 'Utilities',
#   'created_at': '2023-10-25T09:55:33.624895'},
#  {'id': 95,
#   'vendor': 'Google',
#   'data': 'Invoice data for m23Rk6toXo',
#   'amount': 9748.09,
#   'category': 'Internet',
#   'created_at': '2024-09-15T09:55:33.624895'},
#  {'id': 96,
#   'vendor': 'Sony',
#   'data': 'Invoice data for CyxybYAPUF',
#   'amount': 232.32,
#   'category': 'Software',
#   'created_at': '2025-03-16T09:55:33.624895'},
#  {'id': 97,
#   'vendor': 'Dell',
#   'data': 'Invoice data for UG7GSVSEOB',
#   'amount': 1161.78,
#   'category': 'Utilities',
#   'created_at': '2023-09-30T09:55:33.624895'},
#  {'id': 98,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for 3WhlJoI7hi',
#   'amount': 5407.91,
#   'category': 'Accessories',
#   'created_at': '2025-03-07T09:55:33.624895'},
#  {'id': 99,
#   'vendor': 'Google',
#   'data': 'Invoice data for oY7nzfnSUP',
#   'amount': 1667.45,
#   'category': 'Software',
#   'created_at': '2025-06-02T09:55:33.624895'},
#  {'id': 100,
#   'vendor': 'Dell',
#   'data': 'Invoice data for 2TK2TVLWRK',
#   'amount': 7002.88,
#   'category': 'Software',
#   'created_at': '2023-08-27T09:55:33.624895'},
#  {'id': 101,
#   'vendor': 'Dell',
#   'data': 'Invoice data for 3nk3WnbH4B',
#   'amount': 6785.75,
#   'category': 'Internet',
#   'created_at': '2024-04-16T09:55:33.624895'},
#  {'id': 102,
#   'vendor': 'Apple',
#   'data': 'Invoice data for QohXpeao3q',
#   'amount': 8023.78,
#   'category': 'Internet',
#   'created_at': '2025-04-17T09:55:33.624895'},
#  {'id': 103,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for qkJRNcvGby',
#   'amount': 2061.24,
#   'category': 'Electricity',
#   'created_at': '2023-11-17T09:55:33.624895'},
#  {'id': 104,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 2MqvgBeWq4',
#   'amount': 3513.36,
#   'category': 'Computers',
#   'created_at': '2024-10-31T09:55:33.624895'},
#  {'id': 105,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for Kpj4XI5BAm',
#   'amount': 7612.51,
#   'category': 'Accessories',
#   'created_at': '2023-08-10T09:55:33.625896'},
#  {'id': 106,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for qWxQl0uORC',
#   'amount': 1267.14,
#   'category': 'Computers',
#   'created_at': '2024-11-13T09:55:33.625896'},
#  {'id': 107,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for ElRfGWUw5e',
#   'amount': 6348.33,
#   'category': 'Accessories',
#   'created_at': '2025-01-23T09:55:33.625896'},
#  {'id': 108,
#   'vendor': 'Google',
#   'data': 'Invoice data for jMcJ7Zs6X3',
#   'amount': 5411.82,
#   'category': 'Accessories',
#   'created_at': '2024-03-12T09:55:33.625896'},
#  {'id': 109,
#   'vendor': 'Dell',
#   'data': 'Invoice data for TqNws04itC',
#   'amount': 7587.04,
#   'category': 'Accessories',
#   'created_at': '2024-09-19T09:55:33.625896'},
#  {'id': 110,
#   'vendor': 'Google',
#   'data': 'Invoice data for otvKwpDsBl',
#   'amount': 3427.84,
#   'category': 'Software',
#   'created_at': '2024-12-20T09:55:33.625896'},
#  {'id': 111,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for N5OcZT6olD',
#   'amount': 8483.25,
#   'category': 'Software',
#   'created_at': '2025-01-09T09:55:33.625896'},
#  {'id': 112,
#   'vendor': 'Dell',
#   'data': 'Invoice data for lWYhYhSWUA',
#   'amount': 2068.24,
#   'category': 'Software',
#   'created_at': '2023-10-13T09:55:33.625896'},
#  {'id': 113,
#   'vendor': 'Google',
#   'data': 'Invoice data for 9aMrVf2PJU',
#   'amount': 1973.4,
#   'category': 'Utilities',
#   'created_at': '2024-01-06T09:55:33.625896'},
#  {'id': 114,
#   'vendor': 'Apple',
#   'data': 'Invoice data for uXctG4QOeo',
#   'amount': 1097.72,
#   'category': 'Electricity',
#   'created_at': '2024-11-18T09:55:33.625896'},
#  {'id': 115,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for BcCDITQS0o',
#   'amount': 3372.22,
#   'category': 'Electricity',
#   'created_at': '2025-07-05T09:55:33.626903'},
#  {'id': 116,
#   'vendor': 'Apple',
#   'data': 'Invoice data for VDlISX1Hcg',
#   'amount': 9543.0,
#   'category': 'Electricity',
#   'created_at': '2023-12-22T09:55:33.626903'},
#  {'id': 117,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for mMEqksYDb2',
#   'amount': 1236.31,
#   'category': 'Software',
#   'created_at': '2023-08-17T09:55:33.626903'},
#  {'id': 118,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for LGqfUUijcS',
#   'amount': 3414.41,
#   'category': 'Internet',
#   'created_at': '2024-02-22T09:55:33.626903'},
#  {'id': 119,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for yGfgSvAljh',
#   'amount': 5625.65,
#   'category': 'Electricity',
#   'created_at': '2023-10-31T09:55:33.626903'},
#  {'id': 120,
#   'vendor': 'Apple',
#   'data': 'Invoice data for AAFsDcTHZw',
#   'amount': 2608.24,
#   'category': 'Accessories',
#   'created_at': '2024-03-23T09:55:33.626903'},
#  {'id': 121,
#   'vendor': 'Sony',
#   'data': 'Invoice data for aqBxoGby6o',
#   'amount': 1648.43,
#   'category': 'Computers',
#   'created_at': '2025-02-10T09:55:33.626903'},
#  {'id': 122,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for FteZ3Di537',
#   'amount': 9704.71,
#   'category': 'Electricity',
#   'created_at': '2023-09-14T09:55:33.626903'},
#  {'id': 123,
#   'vendor': 'Dell',
#   'data': 'Invoice data for 96cBaPXnR9',
#   'amount': 6815.21,
#   'category': 'Utilities',
#   'created_at': '2024-02-28T09:55:33.626903'},
#  {'id': 124,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for cyauqm3FgC',
#   'amount': 3857.2,
#   'category': 'Software',
#   'created_at': '2024-01-19T09:55:33.626903'},
#  {'id': 125,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for HbWvlVMeJP',
#   'amount': 8302.71,
#   'category': 'Accessories',
#   'created_at': '2024-05-31T09:55:33.626903'},
#  {'id': 126,
#   'vendor': 'Dell',
#   'data': 'Invoice data for TTdKlQfJrG',
#   'amount': 132.17,
#   'category': 'Internet',
#   'created_at': '2024-04-06T09:55:33.626903'},
#  {'id': 127,
#   'vendor': 'Apple',
#   'data': 'Invoice data for tq5ZNN28wu',
#   'amount': 4401.81,
#   'category': 'Computers',
#   'created_at': '2024-01-24T09:55:33.626903'},
#  {'id': 128,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for ZDvAEw5Cro',
#   'amount': 9838.41,
#   'category': 'Utilities',
#   'created_at': '2024-02-22T09:55:33.626903'},
#  {'id': 129,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for kr0skuZfv5',
#   'amount': 803.56,
#   'category': 'Internet',
#   'created_at': '2024-05-28T09:55:33.626903'},
#  {'id': 130,
#   'vendor': 'Sony',
#   'data': 'Invoice data for rwunZ1gQw1',
#   'amount': 2468.05,
#   'category': 'Software',
#   'created_at': '2025-01-27T09:55:33.626903'},
#  {'id': 131,
#   'vendor': 'Apple',
#   'data': 'Invoice data for irZkKlyWga',
#   'amount': 5778.35,
#   'category': 'Electricity',
#   'created_at': '2025-06-15T09:55:33.626903'},
#  {'id': 132,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for FFNeMHANza',
#   'amount': 4954.22,
#   'category': 'Accessories',
#   'created_at': '2024-12-19T09:55:33.626903'},
#  {'id': 133,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for L2oPKMz5lm',
#   'amount': 6888.08,
#   'category': 'Electricity',
#   'created_at': '2024-02-09T09:55:33.626903'},
#  {'id': 134,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for y3sttqBNd9',
#   'amount': 7900.65,
#   'category': 'Computers',
#   'created_at': '2023-07-25T09:55:33.626903'},
#  {'id': 135,
#   'vendor': 'Dell',
#   'data': 'Invoice data for TQDcaQq8Dq',
#   'amount': 5880.32,
#   'category': 'Software',
#   'created_at': '2023-09-03T09:55:33.626903'},
#  {'id': 136,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for yPJoLrD6Qd',
#   'amount': 3025.98,
#   'category': 'Accessories',
#   'created_at': '2025-07-13T09:55:33.627901'},
#  {'id': 137,
#   'vendor': 'Apple',
#   'data': 'Invoice data for dXVYIGgUTR',
#   'amount': 3760.38,
#   'category': 'Software',
#   'created_at': '2023-11-06T09:55:33.627901'},
#  {'id': 138,
#   'vendor': 'Sony',
#   'data': 'Invoice data for RENrrX5Tye',
#   'amount': 486.88,
#   'category': 'Internet',
#   'created_at': '2025-02-03T09:55:33.627901'},
#  {'id': 139,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for BP1OdwhtPQ',
#   'amount': 1644.86,
#   'category': 'Electricity',
#   'created_at': '2023-10-13T09:55:33.627901'},
#  {'id': 140,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for CAfNX6WdGh',
#   'amount': 894.59,
#   'category': 'Software',
#   'created_at': '2023-11-17T09:55:33.627901'},
#  {'id': 141,
#   'vendor': 'Google',
#   'data': 'Invoice data for 9jQf57IBNA',
#   'amount': 2163.77,
#   'category': 'Electricity',
#   'created_at': '2025-03-09T09:55:33.627901'},
#  {'id': 142,
#   'vendor': 'Google',
#   'data': 'Invoice data for YgdYmjqWF6',
#   'amount': 4091.02,
#   'category': 'Software',
#   'created_at': '2024-05-22T09:55:33.627901'},
#  {'id': 143,
#   'vendor': 'Google',
#   'data': 'Invoice data for F16dYnxwtL',
#   'amount': 3980.2,
#   'category': 'Utilities',
#   'created_at': '2025-03-22T09:55:33.627901'},
#  {'id': 144,
#   'vendor': 'Sony',
#   'data': 'Invoice data for AOSrMN4Iyk',
#   'amount': 3495.69,
#   'category': 'Computers',
#   'created_at': '2025-06-10T09:55:33.627901'},
#  {'id': 145,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for nrKNlIkC3R',
#   'amount': 4781.95,
#   'category': 'Internet',
#   'created_at': '2024-10-10T09:55:33.627901'},
#  {'id': 146,
#   'vendor': 'Google',
#   'data': 'Invoice data for LHQbpR9UYg',
#   'amount': 5615.27,
#   'category': 'Software',
#   'created_at': '2024-11-19T09:55:33.627901'},
#  {'id': 147,
#   'vendor': 'Google',
#   'data': 'Invoice data for ciqWGPmKX6',
#   'amount': 1774.69,
#   'category': 'Utilities',
#   'created_at': '2023-09-10T09:55:33.627901'},
#  {'id': 148,
#   'vendor': 'Sony',
#   'data': 'Invoice data for a70JHvr9Tm',
#   'amount': 1679.38,
#   'category': 'Software',
#   'created_at': '2023-12-23T09:55:33.627901'},
#  {'id': 149,
#   'vendor': 'Apple',
#   'data': 'Invoice data for rFCgaRyNJP',
#   'amount': 6476.11,
#   'category': 'Internet',
#   'created_at': '2025-01-30T09:55:33.627901'},
#  {'id': 150,
#   'vendor': 'Apple',
#   'data': 'Invoice data for kJ5x9slXCd',
#   'amount': 306.35,
#   'category': 'Accessories',
#   'created_at': '2024-03-27T09:55:33.627901'},
#  {'id': 151,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for rPBPs3Hk9I',
#   'amount': 4404.45,
#   'category': 'Internet',
#   'created_at': '2024-06-02T09:55:33.627901'},
#  {'id': 152,
#   'vendor': 'Sony',
#   'data': 'Invoice data for MMNO8gIKWF',
#   'amount': 2330.81,
#   'category': 'Accessories',
#   'created_at': '2024-03-22T09:55:33.627901'},
#  {'id': 153,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for SL7jDDzjY3',
#   'amount': 4472.26,
#   'category': 'Internet',
#   'created_at': '2023-12-23T09:55:33.627901'},
#  {'id': 154,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for N2qKWelBLx',
#   'amount': 8950.79,
#   'category': 'Electricity',
#   'created_at': '2024-05-17T09:55:33.627901'},
#  {'id': 155,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for Rs6r2vwe9X',
#   'amount': 7226.82,
#   'category': 'Utilities',
#   'created_at': '2024-03-31T09:55:33.627901'},
#  {'id': 156,
#   'vendor': 'Dell',
#   'data': 'Invoice data for k0nRdYX2kx',
#   'amount': 2666.92,
#   'category': 'Utilities',
#   'created_at': '2023-10-09T09:55:33.627901'},
#  {'id': 157,
#   'vendor': 'Dell',
#   'data': 'Invoice data for A0tIq0yv5W',
#   'amount': 4679.75,
#   'category': 'Computers',
#   'created_at': '2024-10-29T09:55:33.627901'},
#  {'id': 158,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for DjPBXcBRRm',
#   'amount': 5287.86,
#   'category': 'Electricity',
#   'created_at': '2024-12-16T09:55:33.627901'},
#  {'id': 159,
#   'vendor': 'Google',
#   'data': 'Invoice data for 0Zzqz7pSaW',
#   'amount': 2360.11,
#   'category': 'Computers',
#   'created_at': '2024-08-28T09:55:33.628902'},
#  {'id': 160,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for IO3hjRV9fv',
#   'amount': 1816.21,
#   'category': 'Utilities',
#   'created_at': '2025-07-07T09:55:33.628902'},
#  {'id': 161,
#   'vendor': 'Google',
#   'data': 'Invoice data for JCrNpsLAC1',
#   'amount': 1703.6,
#   'category': 'Computers',
#   'created_at': '2024-04-15T09:55:33.628902'},
#  {'id': 162,
#   'vendor': 'Google',
#   'data': 'Invoice data for sgJtkafx9X',
#   'amount': 1140.91,
#   'category': 'Utilities',
#   'created_at': '2024-06-22T09:55:33.628902'},
#  {'id': 163,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 7yQbKQobj0',
#   'amount': 6029.64,
#   'category': 'Electricity',
#   'created_at': '2024-09-12T09:55:33.628902'},
#  {'id': 164,
#   'vendor': 'Apple',
#   'data': 'Invoice data for NpBFduQsKR',
#   'amount': 4397.63,
#   'category': 'Computers',
#   'created_at': '2023-12-23T09:55:33.628902'},
#  {'id': 165,
#   'vendor': 'Dell',
#   'data': 'Invoice data for Mn9lDr72CA',
#   'amount': 9376.26,
#   'category': 'Accessories',
#   'created_at': '2024-04-29T09:55:33.628902'},
#  {'id': 166,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for 3WaEQ3Ek1O',
#   'amount': 7091.0,
#   'category': 'Accessories',
#   'created_at': '2025-01-03T09:55:33.628902'},
#  {'id': 167,
#   'vendor': 'Sony',
#   'data': 'Invoice data for TlJtQW6lh7',
#   'amount': 1808.88,
#   'category': 'Internet',
#   'created_at': '2024-02-02T09:55:33.628902'},
#  {'id': 168,
#   'vendor': 'Apple',
#   'data': 'Invoice data for GbpxlMnQnJ',
#   'amount': 361.75,
#   'category': 'Computers',
#   'created_at': '2023-07-29T09:55:33.628902'},
#  {'id': 169,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for 55YFLAvuPY',
#   'amount': 9253.57,
#   'category': 'Utilities',
#   'created_at': '2025-04-21T09:55:33.628902'},
#  {'id': 170,
#   'vendor': 'Google',
#   'data': 'Invoice data for 4r0OMI8EVv',
#   'amount': 2764.88,
#   'category': 'Software',
#   'created_at': '2023-10-24T09:55:33.628902'},
#  {'id': 171,
#   'vendor': 'Google',
#   'data': 'Invoice data for AIpixheSHV',
#   'amount': 8164.86,
#   'category': 'Computers',
#   'created_at': '2023-12-11T09:55:33.628902'},
#  {'id': 172,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for FGKnAqCI4m',
#   'amount': 4746.22,
#   'category': 'Software',
#   'created_at': '2024-12-03T09:55:33.628902'},
#  {'id': 173,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for wHFtz9M1I8',
#   'amount': 541.18,
#   'category': 'Accessories',
#   'created_at': '2025-05-05T09:55:33.628902'},
#  {'id': 174,
#   'vendor': 'Dell',
#   'data': 'Invoice data for Xsjy9MVqog',
#   'amount': 2818.49,
#   'category': 'Electricity',
#   'created_at': '2024-09-04T09:55:33.628902'},
#  {'id': 175,
#   'vendor': 'Apple',
#   'data': 'Invoice data for aS7bzGOJGX',
#   'amount': 5397.45,
#   'category': 'Software',
#   'created_at': '2023-12-05T09:55:33.628902'},
#  {'id': 176,
#   'vendor': 'Sony',
#   'data': 'Invoice data for DADlAjgbrA',
#   'amount': 8102.55,
#   'category': 'Software',
#   'created_at': '2025-05-09T09:55:33.628902'},
#  {'id': 177,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for ay9s7HkuTZ',
#   'amount': 1073.16,
#   'category': 'Internet',
#   'created_at': '2024-04-24T09:55:33.628902'},
#  {'id': 178,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for qey1i0xj4k',
#   'amount': 7815.32,
#   'category': 'Electricity',
#   'created_at': '2024-06-07T09:55:33.628902'},
#  {'id': 179,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for qRO7t2iXzk',
#   'amount': 7065.24,
#   'category': 'Computers',
#   'created_at': '2024-06-14T09:55:33.628902'},
#  {'id': 180,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 6IfXHh9fMV',
#   'amount': 1703.65,
#   'category': 'Computers',
#   'created_at': '2024-05-14T09:55:33.628902'},
#  {'id': 181,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for K2h9wNYTRI',
#   'amount': 9237.85,
#   'category': 'Utilities',
#   'created_at': '2025-06-07T09:55:33.629902'},
#  {'id': 182,
#   'vendor': 'Sony',
#   'data': 'Invoice data for Laoyau7XjH',
#   'amount': 5759.19,
#   'category': 'Electricity',
#   'created_at': '2024-01-30T09:55:33.629902'},
#  {'id': 183,
#   'vendor': 'Dell',
#   'data': 'Invoice data for SQPRrgFmxA',
#   'amount': 278.94,
#   'category': 'Utilities',
#   'created_at': '2023-11-30T09:55:33.629902'},
#  {'id': 184,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for 5bK8ShpBAA',
#   'amount': 6811.24,
#   'category': 'Utilities',
#   'created_at': '2024-04-20T09:55:33.629902'},
#  {'id': 185,
#   'vendor': 'Apple',
#   'data': 'Invoice data for WzHaCAa0QV',
#   'amount': 9216.63,
#   'category': 'Accessories',
#   'created_at': '2023-08-09T09:55:33.629902'},
#  {'id': 186,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for 05CTB2oBuj',
#   'amount': 316.37,
#   'category': 'Accessories',
#   'created_at': '2024-11-30T09:55:33.629902'},
#  {'id': 187,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for StuZweADFL',
#   'amount': 3542.16,
#   'category': 'Internet',
#   'created_at': '2024-07-18T09:55:33.629902'},
#  {'id': 188,
#   'vendor': 'Sony',
#   'data': 'Invoice data for dOKXSlBOYc',
#   'amount': 9760.25,
#   'category': 'Computers',
#   'created_at': '2024-11-09T09:55:33.629902'},
#  {'id': 189,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for KnlzkZp8SC',
#   'amount': 5585.6,
#   'category': 'Software',
#   'created_at': '2024-06-16T09:55:33.629902'},
#  {'id': 190,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for wC8HHqOCSe',
#   'amount': 4254.98,
#   'category': 'Electricity',
#   'created_at': '2024-02-11T09:55:33.629902'},
#  {'id': 191,
#   'vendor': 'Google',
#   'data': 'Invoice data for dqIk7lKCm9',
#   'amount': 9482.1,
#   'category': 'Utilities',
#   'created_at': '2024-08-20T09:55:33.630975'},
#  {'id': 192,
#   'vendor': 'Sony',
#   'data': 'Invoice data for jLvhDejj1N',
#   'amount': 732.78,
#   'category': 'Internet',
#   'created_at': '2024-02-11T09:55:33.630975'},
#  {'id': 193,
#   'vendor': 'Sony',
#   'data': 'Invoice data for Np0BGiDHAk',
#   'amount': 5689.34,
#   'category': 'Internet',
#   'created_at': '2024-04-12T09:55:33.630975'},
#  {'id': 194,
#   'vendor': 'Dell',
#   'data': 'Invoice data for Zb2OPf7xD5',
#   'amount': 5273.21,
#   'category': 'Utilities',
#   'created_at': '2025-01-16T09:55:33.630975'},
#  {'id': 195,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for 3frIx7mWiW',
#   'amount': 3202.88,
#   'category': 'Computers',
#   'created_at': '2024-04-29T09:55:33.630975'},
#  {'id': 196,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for l3YAsZmToZ',
#   'amount': 8002.67,
#   'category': 'Accessories',
#   'created_at': '2024-07-06T09:55:33.630975'},
#  {'id': 197,
#   'vendor': 'Sony',
#   'data': 'Invoice data for SK7HL87twH',
#   'amount': 5857.81,
#   'category': 'Utilities',
#   'created_at': '2025-03-27T09:55:33.630975'},
#  {'id': 198,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for 5o7MfyMX63',
#   'amount': 1825.12,
#   'category': 'Computers',
#   'created_at': '2023-12-03T09:55:33.630975'},
#  {'id': 199,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for 9hgIPjmV0p',
#   'amount': 2804.7,
#   'category': 'Electricity',
#   'created_at': '2025-02-25T09:55:33.630975'},
#  {'id': 200,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for WTkaxigxha',
#   'amount': 3949.68,
#   'category': 'Electricity',
#   'created_at': '2024-04-22T09:55:33.630975'},
#  {'id': 201,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for HBG7HGhnuT',
#   'amount': 3898.57,
#   'category': 'Utilities',
#   'created_at': '2024-06-02T09:55:33.630975'},
#  {'id': 202,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for jGnXT5TWRd',
#   'amount': 4232.68,
#   'category': 'Accessories',
#   'created_at': '2024-07-05T09:55:33.630975'},
#  {'id': 203,
#   'vendor': 'Dell',
#   'data': 'Invoice data for iGA3tH2Dgo',
#   'amount': 8627.27,
#   'category': 'Electricity',
#   'created_at': '2025-06-20T09:55:33.630975'},
#  {'id': 204,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for DgdCftwybY',
#   'amount': 5054.35,
#   'category': 'Utilities',
#   'created_at': '2024-03-03T09:55:33.630975'},
#  {'id': 205,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for lwPsVgvhYs',
#   'amount': 9348.77,
#   'category': 'Computers',
#   'created_at': '2024-03-15T09:55:33.630975'},
#  {'id': 206,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for lfoKfOAQa3',
#   'amount': 9161.27,
#   'category': 'Software',
#   'created_at': '2024-02-25T09:55:33.630975'},
#  {'id': 207,
#   'vendor': 'Google',
#   'data': 'Invoice data for SWpAiJjDaL',
#   'amount': 8115.25,
#   'category': 'Computers',
#   'created_at': '2025-05-20T09:55:33.630975'},
#  {'id': 208,
#   'vendor': 'Apple',
#   'data': 'Invoice data for fRSDVpIweB',
#   'amount': 7509.52,
#   'category': 'Accessories',
#   'created_at': '2025-01-19T09:55:33.630975'},
#  {'id': 209,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for r9TuieO5CX',
#   'amount': 9163.92,
#   'category': 'Electricity',
#   'created_at': '2024-08-03T09:55:33.631988'},
#  {'id': 210,
#   'vendor': 'Google',
#   'data': 'Invoice data for hbaZayhgEJ',
#   'amount': 1845.25,
#   'category': 'Software',
#   'created_at': '2023-07-28T09:55:33.631988'},
#  {'id': 211,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for LjhZaDGraP',
#   'amount': 501.27,
#   'category': 'Internet',
#   'created_at': '2024-11-05T09:55:33.631988'},
#  {'id': 212,
#   'vendor': 'Apple',
#   'data': 'Invoice data for Jj5z0JjbTI',
#   'amount': 7240.95,
#   'category': 'Electricity',
#   'created_at': '2023-10-28T09:55:33.631988'},
#  {'id': 213,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for HLiuRZHtbw',
#   'amount': 9834.6,
#   'category': 'Computers',
#   'created_at': '2023-11-16T09:55:33.631988'},
#  {'id': 214,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for 35A5ZilgQU',
#   'amount': 3789.29,
#   'category': 'Utilities',
#   'created_at': '2024-07-01T09:55:33.631988'},
#  {'id': 215,
#   'vendor': 'Apple',
#   'data': 'Invoice data for QzcPmv86g7',
#   'amount': 5680.26,
#   'category': 'Internet',
#   'created_at': '2024-07-01T09:55:33.631988'},
#  {'id': 216,
#   'vendor': 'Google',
#   'data': 'Invoice data for 2Cy0KBPTIX',
#   'amount': 2965.71,
#   'category': 'Accessories',
#   'created_at': '2024-09-15T09:55:33.631988'},
#  {'id': 217,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 2YWz1XbgwC',
#   'amount': 4709.23,
#   'category': 'Utilities',
#   'created_at': '2024-08-14T09:55:33.631988'},
#  {'id': 218,
#   'vendor': 'Dell',
#   'data': 'Invoice data for 1pVHbFgIjC',
#   'amount': 9512.0,
#   'category': 'Internet',
#   'created_at': '2023-08-13T09:55:33.631988'},
#  {'id': 219,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for MKe0oe4opz',
#   'amount': 392.4,
#   'category': 'Accessories',
#   'created_at': '2025-03-07T09:55:33.631988'},
#  {'id': 220,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for 6hGsyEmX0S',
#   'amount': 1306.76,
#   'category': 'Internet',
#   'created_at': '2025-04-20T09:55:33.631988'},
#  {'id': 221,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for whNTrGYT8b',
#   'amount': 2427.46,
#   'category': 'Internet',
#   'created_at': '2024-07-19T09:55:33.631988'},
#  {'id': 222,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for RzqUlFzUpr',
#   'amount': 5243.28,
#   'category': 'Computers',
#   'created_at': '2024-11-24T09:55:33.631988'},
#  {'id': 223,
#   'vendor': 'Dell',
#   'data': 'Invoice data for mjdWOmoEZG',
#   'amount': 9235.72,
#   'category': 'Accessories',
#   'created_at': '2023-10-05T09:55:33.632998'},
#  {'id': 224,
#   'vendor': 'Apple',
#   'data': 'Invoice data for TIvCGWk100',
#   'amount': 9115.26,
#   'category': 'Internet',
#   'created_at': '2025-04-04T09:55:33.632998'},
#  {'id': 225,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for ej6PRLheKA',
#   'amount': 2686.18,
#   'category': 'Computers',
#   'created_at': '2024-11-19T09:55:33.632998'},
#  {'id': 226,
#   'vendor': 'Google',
#   'data': 'Invoice data for MwKSagpBna',
#   'amount': 6748.63,
#   'category': 'Computers',
#   'created_at': '2025-01-01T09:55:33.632998'},
#  {'id': 227,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for 22jD4FoXJn',
#   'amount': 7594.49,
#   'category': 'Electricity',
#   'created_at': '2024-11-16T09:55:33.632998'},
#  {'id': 228,
#   'vendor': 'Dell',
#   'data': 'Invoice data for rTSXlz2naU',
#   'amount': 3434.63,
#   'category': 'Computers',
#   'created_at': '2025-07-09T09:55:33.632998'},
#  {'id': 229,
#   'vendor': 'Apple',
#   'data': 'Invoice data for Nvx3xYPy5Q',
#   'amount': 8969.6,
#   'category': 'Accessories',
#   'created_at': '2024-10-06T09:55:33.632998'},
#  {'id': 230,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for URXXdzEymb',
#   'amount': 834.22,
#   'category': 'Electricity',
#   'created_at': '2024-11-03T09:55:33.632998'},
#  {'id': 231,
#   'vendor': 'Apple',
#   'data': 'Invoice data for k1TG0BjHT2',
#   'amount': 6095.11,
#   'category': 'Internet',
#   'created_at': '2024-06-28T09:55:33.632998'},
#  {'id': 232,
#   'vendor': 'Sony',
#   'data': 'Invoice data for hqu7yYGUGX',
#   'amount': 5519.18,
#   'category': 'Utilities',
#   'created_at': '2023-09-04T09:55:33.632998'},
#  {'id': 233,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for XfRDc7hfxJ',
#   'amount': 4473.24,
#   'category': 'Accessories',
#   'created_at': '2024-02-12T09:55:33.632998'},
#  {'id': 234,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for KUh4zrxIU7',
#   'amount': 4194.64,
#   'category': 'Utilities',
#   'created_at': '2024-02-22T09:55:33.632998'},
#  {'id': 235,
#   'vendor': 'Google',
#   'data': 'Invoice data for 6LYDR7qHjc',
#   'amount': 2734.84,
#   'category': 'Electricity',
#   'created_at': '2024-06-10T09:55:33.632998'},
#  {'id': 236,
#   'vendor': 'Google',
#   'data': 'Invoice data for lcHwnaEnZp',
#   'amount': 7069.36,
#   'category': 'Internet',
#   'created_at': '2024-05-08T09:55:33.632998'},
#  {'id': 237,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for QlYHjPGIOc',
#   'amount': 4775.29,
#   'category': 'Electricity',
#   'created_at': '2025-01-04T09:55:33.632998'},
#  {'id': 238,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for J7HrwOm7Tv',
#   'amount': 7109.01,
#   'category': 'Internet',
#   'created_at': '2025-06-14T09:55:33.632998'},
#  {'id': 239,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for zC0FscYlS6',
#   'amount': 8815.45,
#   'category': 'Utilities',
#   'created_at': '2023-11-07T09:55:33.632998'},
#  {'id': 240,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for eZl417uAuZ',
#   'amount': 8976.16,
#   'category': 'Software',
#   'created_at': '2024-09-23T09:55:33.632998'},
#  {'id': 241,
#   'vendor': 'Sony',
#   'data': 'Invoice data for aBtJfkFz4U',
#   'amount': 6825.64,
#   'category': 'Internet',
#   'created_at': '2025-04-15T09:55:33.632998'},
#  {'id': 242,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for t8ib1rZV4F',
#   'amount': 3104.3,
#   'category': 'Internet',
#   'created_at': '2024-12-14T09:55:33.632998'},
#  {'id': 243,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for 42cwYelra5',
#   'amount': 5025.22,
#   'category': 'Software',
#   'created_at': '2024-08-11T09:55:33.632998'},
#  {'id': 244,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for 5dm4GjQVyc',
#   'amount': 1480.16,
#   'category': 'Utilities',
#   'created_at': '2025-05-16T09:55:33.632998'},
#  {'id': 245,
#   'vendor': 'Sony',
#   'data': 'Invoice data for Ll8tccOXJS',
#   'amount': 2219.13,
#   'category': 'Computers',
#   'created_at': '2024-05-25T09:55:33.632998'},
#  {'id': 246,
#   'vendor': 'Dell',
#   'data': 'Invoice data for asDOFoVFV9',
#   'amount': 132.48,
#   'category': 'Electricity',
#   'created_at': '2024-06-10T09:55:33.634508'},
#  {'id': 247,
#   'vendor': 'Dell',
#   'data': 'Invoice data for PLUdM3Xuui',
#   'amount': 7875.59,
#   'category': 'Computers',
#   'created_at': '2024-01-22T09:55:33.634508'},
#  {'id': 248,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for wSjikW0BDr',
#   'amount': 6699.45,
#   'category': 'Accessories',
#   'created_at': '2024-05-19T09:55:33.634508'},
#  {'id': 249,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for QiaGZwu6ZY',
#   'amount': 982.23,
#   'category': 'Utilities',
#   'created_at': '2023-11-05T09:55:33.634508'},
#  {'id': 250,
#   'vendor': 'Google',
#   'data': 'Invoice data for 3CtSgMbTA1',
#   'amount': 9173.94,
#   'category': 'Utilities',
#   'created_at': '2025-02-12T09:55:33.634508'},
#  {'id': 251,
#   'vendor': 'Apple',
#   'data': 'Invoice data for tJgk4rwqKt',
#   'amount': 371.99,
#   'category': 'Computers',
#   'created_at': '2025-02-19T09:55:33.634508'},
#  {'id': 252,
#   'vendor': 'Dell',
#   'data': 'Invoice data for iv7WouZaii',
#   'amount': 7384.07,
#   'category': 'Electricity',
#   'created_at': '2023-09-02T09:55:33.634508'},
#  {'id': 253,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for SQTSgBjNvi',
#   'amount': 5533.45,
#   'category': 'Utilities',
#   'created_at': '2023-10-04T09:55:33.634508'},
#  {'id': 254,
#   'vendor': 'Sony',
#   'data': 'Invoice data for NKFlpCX4cQ',
#   'amount': 8949.66,
#   'category': 'Utilities',
#   'created_at': '2025-03-31T09:55:33.634508'},
#  {'id': 255,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for V8gu0XIHSf',
#   'amount': 9362.35,
#   'category': 'Computers',
#   'created_at': '2025-03-09T09:55:33.634508'},
#  {'id': 256,
#   'vendor': 'Dell',
#   'data': 'Invoice data for umyzfqO1s3',
#   'amount': 6505.69,
#   'category': 'Internet',
#   'created_at': '2023-11-15T09:55:33.634508'},
#  {'id': 257,
#   'vendor': 'Dell',
#   'data': 'Invoice data for fQQjrpcClX',
#   'amount': 2423.86,
#   'category': 'Software',
#   'created_at': '2025-01-31T09:55:33.634508'},
#  {'id': 258,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for 2hVCjqiCY5',
#   'amount': 3783.72,
#   'category': 'Utilities',
#   'created_at': '2024-06-12T09:55:33.634508'},
#  {'id': 259,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for FNlBmiSjoE',
#   'amount': 4344.86,
#   'category': 'Accessories',
#   'created_at': '2024-03-21T09:55:33.634508'},
#  {'id': 260,
#   'vendor': 'Apple',
#   'data': 'Invoice data for 9zlDimf73s',
#   'amount': 5698.56,
#   'category': 'Electricity',
#   'created_at': '2023-08-12T09:55:33.634508'},
#  {'id': 261,
#   'vendor': 'Dell',
#   'data': 'Invoice data for K0n6r7wzre',
#   'amount': 2169.46,
#   'category': 'Electricity',
#   'created_at': '2024-08-29T09:55:33.634508'},
#  {'id': 262,
#   'vendor': 'Google',
#   'data': 'Invoice data for MEN1EZlrEL',
#   'amount': 5769.22,
#   'category': 'Utilities',
#   'created_at': '2025-07-08T09:55:33.634508'},
#  {'id': 263,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for QAkv6RnVIk',
#   'amount': 6841.45,
#   'category': 'Internet',
#   'created_at': '2024-07-15T09:55:33.634508'},
#  {'id': 264,
#   'vendor': 'Sony',
#   'data': 'Invoice data for bTNyEBt5kk',
#   'amount': 4235.69,
#   'category': 'Accessories',
#   'created_at': '2024-03-23T09:55:33.634508'},
#  {'id': 265,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for JwTlZ6q6wV',
#   'amount': 8400.06,
#   'category': 'Internet',
#   'created_at': '2023-10-04T09:55:33.634508'},
#  {'id': 266,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for rixhYBszms',
#   'amount': 8141.9,
#   'category': 'Electricity',
#   'created_at': '2024-09-23T09:55:33.634508'},
#  {'id': 267,
#   'vendor': 'Google',
#   'data': 'Invoice data for D71YfrqDDh',
#   'amount': 4975.85,
#   'category': 'Computers',
#   'created_at': '2023-09-23T09:55:33.635525'},
#  {'id': 268,
#   'vendor': 'Dell',
#   'data': 'Invoice data for otzAX4XYvF',
#   'amount': 1511.02,
#   'category': 'Computers',
#   'created_at': '2025-01-29T09:55:33.635525'},
#  {'id': 269,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for Qgnilk46VB',
#   'amount': 8473.0,
#   'category': 'Utilities',
#   'created_at': '2023-12-31T09:55:33.635525'},
#  {'id': 270,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for lyq0srBLoS',
#   'amount': 6554.3,
#   'category': 'Software',
#   'created_at': '2023-12-29T09:55:33.635525'},
#  {'id': 271,
#   'vendor': 'Apple',
#   'data': 'Invoice data for m7bVM2kwmb',
#   'amount': 3267.88,
#   'category': 'Electricity',
#   'created_at': '2024-05-26T09:55:33.635525'},
#  {'id': 272,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for H6STbKfcD7',
#   'amount': 7803.64,
#   'category': 'Electricity',
#   'created_at': '2023-10-25T09:55:33.635525'},
#  {'id': 273,
#   'vendor': 'Sony',
#   'data': 'Invoice data for gMzPbI3p8q',
#   'amount': 6560.35,
#   'category': 'Electricity',
#   'created_at': '2024-01-05T09:55:33.635525'},
#  {'id': 274,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for kCAqT9obmJ',
#   'amount': 6680.71,
#   'category': 'Computers',
#   'created_at': '2024-08-04T09:55:33.635525'},
#  {'id': 275,
#   'vendor': 'Sony',
#   'data': 'Invoice data for S2WB1WKIth',
#   'amount': 1478.22,
#   'category': 'Utilities',
#   'created_at': '2024-06-09T09:55:33.635525'},
#  {'id': 276,
#   'vendor': 'Apple',
#   'data': 'Invoice data for pqb0WVJMCt',
#   'amount': 4995.91,
#   'category': 'Internet',
#   'created_at': '2025-02-10T09:55:33.635525'},
#  {'id': 277,
#   'vendor': 'Dell',
#   'data': 'Invoice data for x2cXU3Flnb',
#   'amount': 6483.4,
#   'category': 'Accessories',
#   'created_at': '2023-09-28T09:55:33.635525'},
#  {'id': 278,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for LBII3sQ5pZ',
#   'amount': 6582.97,
#   'category': 'Computers',
#   'created_at': '2024-02-16T09:55:33.635525'},
#  {'id': 279,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for 2DNg8u5EAb',
#   'amount': 51.56,
#   'category': 'Utilities',
#   'created_at': '2023-12-31T09:55:33.635525'},
#  {'id': 280,
#   'vendor': 'Sony',
#   'data': 'Invoice data for wnkvCCG2ZD',
#   'amount': 5873.71,
#   'category': 'Accessories',
#   'created_at': '2024-01-15T09:55:33.635525'},
#  {'id': 281,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for 0FX5HNXlvn',
#   'amount': 3407.49,
#   'category': 'Electricity',
#   'created_at': '2023-09-20T09:55:33.635525'},
#  {'id': 282,
#   'vendor': 'Lenovo',
# ...
#   'category': 'Software',
#   'created_at': '2024-04-03T09:55:33.675522'},
#  {'id': 908,
#   'vendor': 'Sony',
#   'data': 'Invoice data for JI4h2JPKIr',
#   'amount': 8541.1,
#   'category': 'Utilities',
#   'created_at': '2024-01-14T09:55:33.675522'},
#  {'id': 909,
#   'vendor': 'Apple',
#   'data': 'Invoice data for 8Tv2VIk8WT',
#   'amount': 2693.37,
#   'category': 'Accessories',
#   'created_at': '2024-07-07T09:55:33.675522'},
#  {'id': 910,
#   'vendor': 'Google',
#   'data': 'Invoice data for wjrBmLOuU7',
#   'amount': 3897.7,
#   'category': 'Utilities',
#   'created_at': '2023-07-26T09:55:34.025337'},
#  {'id': 911,
#   'vendor': 'Sony',
#   'data': 'Invoice data for dZY2DC3hmN',
#   'amount': 5939.38,
#   'category': 'Electricity',
#   'created_at': '2023-10-19T09:55:34.025337'},
#  {'id': 912,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for iPgbtQWg1z',
#   'amount': 3350.42,
#   'category': 'Computers',
#   'created_at': '2024-01-29T09:55:34.025337'},
#  {'id': 913,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for AqVDgDOQE0',
#   'amount': 7183.48,
#   'category': 'Utilities',
#   'created_at': '2024-02-05T09:55:34.025337'},
#  {'id': 914,
#   'vendor': 'Google',
#   'data': 'Invoice data for CmYyhxTSWe',
#   'amount': 5655.87,
#   'category': 'Computers',
#   'created_at': '2025-04-27T09:55:34.025337'},
#  {'id': 915,
#   'vendor': 'Google',
#   'data': 'Invoice data for zyM2VnEYRI',
#   'amount': 2261.37,
#   'category': 'Electricity',
#   'created_at': '2025-01-23T09:55:34.025337'},
#  {'id': 916,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for NH9V4FhLoy',
#   'amount': 8737.47,
#   'category': 'Computers',
#   'created_at': '2023-08-07T09:55:34.025337'},
#  {'id': 917,
#   'vendor': 'Dell',
#   'data': 'Invoice data for SY22xKSfXq',
#   'amount': 7044.15,
#   'category': 'Software',
#   'created_at': '2023-11-14T09:55:34.025337'},
#  {'id': 918,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for rrYqz6oW6j',
#   'amount': 6520.0,
#   'category': 'Internet',
#   'created_at': '2025-05-28T09:55:34.025337'},
#  {'id': 919,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for Kn2CQMrxJ1',
#   'amount': 3879.33,
#   'category': 'Accessories',
#   'created_at': '2024-12-02T09:55:34.025337'},
#  {'id': 920,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for AuKMMNL2T4',
#   'amount': 2376.83,
#   'category': 'Internet',
#   'created_at': '2024-09-06T09:55:34.025337'},
#  {'id': 921,
#   'vendor': 'Dell',
#   'data': 'Invoice data for RQIG3Wuc9L',
#   'amount': 255.91,
#   'category': 'Electricity',
#   'created_at': '2024-05-03T09:55:34.025337'},
#  {'id': 922,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for XJbjXV6gI2',
#   'amount': 6367.74,
#   'category': 'Utilities',
#   'created_at': '2025-03-25T09:55:34.025337'},
#  {'id': 923,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for 8GO04uMc7C',
#   'amount': 5651.76,
#   'category': 'Computers',
#   'created_at': '2024-12-03T09:55:34.026339'},
#  {'id': 924,
#   'vendor': 'Sony',
#   'data': 'Invoice data for XzYpNMWvgm',
#   'amount': 4615.13,
#   'category': 'Computers',
#   'created_at': '2023-12-06T09:55:34.026339'},
#  {'id': 925,
#   'vendor': 'Sony',
#   'data': 'Invoice data for D4ER867Xsj',
#   'amount': 5701.73,
#   'category': 'Internet',
#   'created_at': '2023-10-15T09:55:34.026339'},
#  {'id': 926,
#   'vendor': 'Apple',
#   'data': 'Invoice data for Y93BMzfbqH',
#   'amount': 7118.67,
#   'category': 'Accessories',
#   'created_at': '2024-10-18T09:55:34.026339'},
#  {'id': 927,
#   'vendor': 'Google',
#   'data': 'Invoice data for 3M3o4mTNzN',
#   'amount': 4419.08,
#   'category': 'Computers',
#   'created_at': '2023-12-28T09:55:34.026339'},
#  {'id': 928,
#   'vendor': 'Google',
#   'data': 'Invoice data for rb2bQHPrdh',
#   'amount': 3076.21,
#   'category': 'Computers',
#   'created_at': '2024-12-11T09:55:34.026339'},
#  {'id': 929,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for Cn2Jjz0ITS',
#   'amount': 6038.1,
#   'category': 'Internet',
#   'created_at': '2024-07-26T09:55:34.026339'},
#  {'id': 930,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for aCYzBN098z',
#   'amount': 5590.77,
#   'category': 'Utilities',
#   'created_at': '2025-02-16T09:55:34.026339'},
#  {'id': 931,
#   'vendor': 'Dell',
#   'data': 'Invoice data for HncH1USiHf',
#   'amount': 3167.16,
#   'category': 'Computers',
#   'created_at': '2024-01-06T09:55:34.026339'},
#  {'id': 932,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 39AsmBq0OX',
#   'amount': 4050.6,
#   'category': 'Computers',
#   'created_at': '2025-01-08T09:55:34.026339'},
#  {'id': 933,
#   'vendor': 'Apple',
#   'data': 'Invoice data for ggpsvFKcC7',
#   'amount': 7432.79,
#   'category': 'Software',
#   'created_at': '2023-11-22T09:55:34.026339'},
#  {'id': 934,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for VFhP5gHDaN',
#   'amount': 4892.9,
#   'category': 'Electricity',
#   'created_at': '2023-10-25T09:55:34.026339'},
#  {'id': 935,
#   'vendor': 'Google',
#   'data': 'Invoice data for uSWuhw6p0h',
#   'amount': 9850.51,
#   'category': 'Computers',
#   'created_at': '2024-06-03T09:55:34.026339'},
#  {'id': 936,
#   'vendor': 'Google',
#   'data': 'Invoice data for d5ZYXYUFZH',
#   'amount': 2981.59,
#   'category': 'Internet',
#   'created_at': '2024-02-29T09:55:34.026339'},
#  {'id': 937,
#   'vendor': 'Google',
#   'data': 'Invoice data for JWvEDXQ0hh',
#   'amount': 8463.69,
#   'category': 'Software',
#   'created_at': '2024-01-18T09:55:34.026339'},
#  {'id': 938,
#   'vendor': 'Apple',
#   'data': 'Invoice data for EzI9V9MxZY',
#   'amount': 7347.28,
#   'category': 'Internet',
#   'created_at': '2023-09-09T09:55:34.026339'},
#  {'id': 939,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for yHCCpwlyvz',
#   'amount': 3617.43,
#   'category': 'Electricity',
#   'created_at': '2025-02-05T09:55:34.026339'},
#  {'id': 940,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for UnwaVy8k22',
#   'amount': 5050.02,
#   'category': 'Electricity',
#   'created_at': '2023-11-22T09:55:34.026339'},
#  {'id': 941,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for fJwBPomlzt',
#   'amount': 5517.51,
#   'category': 'Internet',
#   'created_at': '2025-02-01T09:55:34.026339'},
#  {'id': 942,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for zsx9doJu28',
#   'amount': 149.5,
#   'category': 'Accessories',
#   'created_at': '2024-09-09T09:55:34.026339'},
#  {'id': 943,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for 9iPD2BwCfO',
#   'amount': 394.12,
#   'category': 'Software',
#   'created_at': '2023-10-23T09:55:34.027337'},
#  {'id': 944,
#   'vendor': 'Sony',
#   'data': 'Invoice data for AA2z7p9HZ2',
#   'amount': 2437.2,
#   'category': 'Accessories',
#   'created_at': '2025-01-04T09:55:34.027337'},
#  {'id': 945,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for GEWCsTkH95',
#   'amount': 4135.6,
#   'category': 'Accessories',
#   'created_at': '2024-01-06T09:55:34.027337'},
#  {'id': 946,
#   'vendor': 'Sony',
#   'data': 'Invoice data for nvW9HYyknN',
#   'amount': 6150.69,
#   'category': 'Computers',
#   'created_at': '2024-06-22T09:55:34.027337'},
#  {'id': 947,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for FqiDK1CwpD',
#   'amount': 7598.78,
#   'category': 'Software',
#   'created_at': '2024-03-01T09:55:34.027337'},
#  {'id': 948,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for mzFhxyehwi',
#   'amount': 2812.57,
#   'category': 'Utilities',
#   'created_at': '2023-11-15T09:55:34.027337'},
#  {'id': 949,
#   'vendor': 'Google',
#   'data': 'Invoice data for b9uusX9GM0',
#   'amount': 99.39,
#   'category': 'Computers',
#   'created_at': '2023-09-10T09:55:34.027337'},
#  {'id': 950,
#   'vendor': 'Google',
#   'data': 'Invoice data for pSsjH6Rnj8',
#   'amount': 9405.13,
#   'category': 'Computers',
#   'created_at': '2025-06-18T09:55:34.027337'},
#  {'id': 951,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for SlRO9NGQqi',
#   'amount': 6926.19,
#   'category': 'Utilities',
#   'created_at': '2024-02-13T09:55:34.027337'},
#  {'id': 952,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for fgUwHESpDl',
#   'amount': 4068.13,
#   'category': 'Electricity',
#   'created_at': '2025-04-11T09:55:34.027337'},
#  {'id': 953,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for qzZ9Q7Lsmv',
#   'amount': 5580.62,
#   'category': 'Computers',
#   'created_at': '2024-08-03T09:55:34.027337'},
#  {'id': 954,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for kVK0R4TPHu',
#   'amount': 2177.08,
#   'category': 'Computers',
#   'created_at': '2024-01-05T09:55:34.027337'},
#  {'id': 955,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for B5y2C9faEh',
#   'amount': 2644.06,
#   'category': 'Accessories',
#   'created_at': '2023-11-22T09:55:34.027337'},
#  {'id': 956,
#   'vendor': 'Dell',
#   'data': 'Invoice data for BVFoUJRVG3',
#   'amount': 2349.44,
#   'category': 'Accessories',
#   'created_at': '2025-02-27T09:55:34.027337'},
#  {'id': 957,
#   'vendor': 'Google',
#   'data': 'Invoice data for ZD3XNCTJdh',
#   'amount': 7806.57,
#   'category': 'Accessories',
#   'created_at': '2024-02-23T09:55:34.027337'},
#  {'id': 958,
#   'vendor': 'Google',
#   'data': 'Invoice data for NWtQK3tgTT',
#   'amount': 4428.23,
#   'category': 'Accessories',
#   'created_at': '2024-05-27T09:55:34.027337'},
#  {'id': 959,
#   'vendor': 'Dell',
#   'data': 'Invoice data for ETraCyOUVc',
#   'amount': 2820.81,
#   'category': 'Utilities',
#   'created_at': '2023-07-22T09:55:34.027337'},
#  {'id': 960,
#   'vendor': 'Apple',
#   'data': 'Invoice data for r3FblswPEe',
#   'amount': 2198.26,
#   'category': 'Electricity',
#   'created_at': '2024-10-09T09:55:34.027337'},
#  {'id': 961,
#   'vendor': 'Sony',
#   'data': 'Invoice data for FwlzmfHhVD',
#   'amount': 6412.24,
#   'category': 'Internet',
#   'created_at': '2023-09-28T09:55:34.027337'},
#  {'id': 962,
#   'vendor': 'Google',
#   'data': 'Invoice data for 9k9rti9NhJ',
#   'amount': 6749.58,
#   'category': 'Accessories',
#   'created_at': '2023-12-14T09:55:34.027337'},
#  {'id': 963,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for ujDBDL2vBg',
#   'amount': 6817.92,
#   'category': 'Accessories',
#   'created_at': '2023-07-31T09:55:34.027337'},
#  {'id': 964,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for uGyElj74bB',
#   'amount': 1076.73,
#   'category': 'Utilities',
#   'created_at': '2024-06-13T09:55:34.028338'},
#  {'id': 965,
#   'vendor': 'Dell',
#   'data': 'Invoice data for sfxxPy97KI',
#   'amount': 7413.91,
#   'category': 'Accessories',
#   'created_at': '2025-07-19T09:55:34.028338'},
#  {'id': 966,
#   'vendor': 'Google',
#   'data': 'Invoice data for uDYFvHtc5t',
#   'amount': 7900.77,
#   'category': 'Computers',
#   'created_at': '2024-04-24T09:55:34.028338'},
#  {'id': 967,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 6wSTRsXBBq',
#   'amount': 835.78,
#   'category': 'Computers',
#   'created_at': '2023-10-03T09:55:34.028338'},
#  {'id': 968,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for DF0xLFXo7j',
#   'amount': 3377.23,
#   'category': 'Computers',
#   'created_at': '2023-11-09T09:55:34.028338'},
#  {'id': 969,
#   'vendor': 'Dell',
#   'data': 'Invoice data for gvIx8JPJfE',
#   'amount': 5763.57,
#   'category': 'Utilities',
#   'created_at': '2024-02-22T09:55:34.028338'},
#  {'id': 970,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 4PZ04KVD66',
#   'amount': 4728.51,
#   'category': 'Electricity',
#   'created_at': '2024-03-24T09:55:34.028338'},
#  {'id': 971,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for vMwGb3Julo',
#   'amount': 6456.02,
#   'category': 'Computers',
#   'created_at': '2025-03-18T09:55:34.028338'},
#  {'id': 972,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for NhpHJ1tWXN',
#   'amount': 8198.84,
#   'category': 'Software',
#   'created_at': '2024-09-15T09:55:34.028338'},
#  {'id': 973,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for tBISOM2Jfn',
#   'amount': 8464.76,
#   'category': 'Utilities',
#   'created_at': '2025-06-28T09:55:34.028338'},
#  {'id': 974,
#   'vendor': 'Dell',
#   'data': 'Invoice data for yN0MiAOffP',
#   'amount': 7449.0,
#   'category': 'Electricity',
#   'created_at': '2024-11-27T09:55:34.028338'},
#  {'id': 975,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for xJMGgO1Dcu',
#   'amount': 878.32,
#   'category': 'Accessories',
#   'created_at': '2023-09-16T09:55:34.028338'},
#  {'id': 976,
#   'vendor': 'Amazon',
#   'data': 'Invoice data for dQDqLgJQ4X',
#   'amount': 790.07,
#   'category': 'Software',
#   'created_at': '2024-11-08T09:55:34.028338'},
#  {'id': 977,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for KTHN0wjTKm',
#   'amount': 1360.21,
#   'category': 'Utilities',
#   'created_at': '2025-03-05T09:55:34.028338'},
#  {'id': 978,
#   'vendor': 'Apple',
#   'data': 'Invoice data for 4vYp5PBHlS',
#   'amount': 3355.31,
#   'category': 'Computers',
#   'created_at': '2024-12-13T09:55:34.028338'},
#  {'id': 979,
#   'vendor': 'Apple',
#   'data': 'Invoice data for XdW0Cb51dA',
#   'amount': 9140.74,
#   'category': 'Internet',
#   'created_at': '2024-12-09T09:55:34.028338'},
#  {'id': 980,
#   'vendor': 'Google',
#   'data': 'Invoice data for ppVNPuR1j7',
#   'amount': 6248.34,
#   'category': 'Software',
#   'created_at': '2025-04-09T09:55:34.028338'},
#  {'id': 981,
#   'vendor': 'Samsung',
#   'data': 'Invoice data for LdV47eOwM0',
#   'amount': 2327.86,
#   'category': 'Accessories',
#   'created_at': '2025-01-02T09:55:34.028338'},
#  {'id': 982,
#   'vendor': 'Apple',
#   'data': 'Invoice data for qTJGk8skIi',
#   'amount': 2750.24,
#   'category': 'Utilities',
#   'created_at': '2023-10-15T09:55:34.028338'},
#  {'id': 983,
#   'vendor': 'Dell',
#   'data': 'Invoice data for j73XSA5H04',
#   'amount': 5195.86,
#   'category': 'Internet',
#   'created_at': '2024-02-15T09:55:34.028338'},
#  {'id': 984,
#   'vendor': 'Apple',
#   'data': 'Invoice data for e6WdLmB6q9',
#   'amount': 3702.98,
#   'category': 'Utilities',
#   'created_at': '2024-03-13T09:55:34.028338'},
#  {'id': 985,
#   'vendor': 'Sony',
#   'data': 'Invoice data for qeV4Bw8mNe',
#   'amount': 9044.78,
#   'category': 'Electricity',
#   'created_at': '2024-02-12T09:55:34.029337'},
#  {'id': 986,
#   'vendor': 'Google',
#   'data': 'Invoice data for lvemyIBttT',
#   'amount': 8111.31,
#   'category': 'Internet',
#   'created_at': '2025-05-31T09:55:34.029337'},
#  {'id': 987,
#   'vendor': 'Apple',
#   'data': 'Invoice data for FARLUkEJiX',
#   'amount': 7410.58,
#   'category': 'Utilities',
#   'created_at': '2025-07-15T09:55:34.029337'},
#  {'id': 988,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for Jrq31MU67W',
#   'amount': 4254.78,
#   'category': 'Utilities',
#   'created_at': '2025-02-23T09:55:34.029337'},
#  {'id': 989,
#   'vendor': 'Google',
#   'data': 'Invoice data for G09yctXZ8z',
#   'amount': 8762.43,
#   'category': 'Computers',
#   'created_at': '2023-12-01T09:55:34.029337'},
#  {'id': 990,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for n3ANchQecf',
#   'amount': 6164.56,
#   'category': 'Electricity',
#   'created_at': '2025-01-22T09:55:34.029337'},
#  {'id': 991,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for 9hX5XfxvVU',
#   'amount': 6144.25,
#   'category': 'Software',
#   'created_at': '2023-12-28T09:55:34.029337'},
#  {'id': 992,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for m1CjJhCHnV',
#   'amount': 4532.75,
#   'category': 'Electricity',
#   'created_at': '2025-07-14T09:55:34.029337'},
#  {'id': 993,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for fTnQzxFr8p',
#   'amount': 3766.28,
#   'category': 'Computers',
#   'created_at': '2024-06-01T09:55:34.029337'},
#  {'id': 994,
#   'vendor': 'Google',
#   'data': 'Invoice data for 51lEhHR2dL',
#   'amount': 8018.03,
#   'category': 'Internet',
#   'created_at': '2024-10-07T09:55:34.029337'},
#  {'id': 995,
#   'vendor': 'Google',
#   'data': 'Invoice data for YUlEu3l5U2',
#   'amount': 9220.58,
#   'category': 'Utilities',
#   'created_at': '2023-12-12T09:55:34.029337'},
#  {'id': 996,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for Voo54YP1oB',
#   'amount': 141.01,
#   'category': 'Internet',
#   'created_at': '2024-05-03T09:55:34.029337'},
#  {'id': 997,
#   'vendor': 'Sony',
#   'data': 'Invoice data for 7tGlwiVhwj',
#   'amount': 8337.75,
#   'category': 'Accessories',
#   'created_at': '2025-01-08T09:55:34.029337'},
#  {'id': 998,
#   'vendor': 'Lenovo',
#   'data': 'Invoice data for M4flI6848f',
#   'amount': 8443.45,
#   'category': 'Software',
#   'created_at': '2025-07-15T09:55:34.029337'},
#  {'id': 999,
#   'vendor': 'Microsoft',
#   'data': 'Invoice data for SK3unh3Btv',
#   'amount': 194.75,
#   'category': 'Electricity',
#   'created_at': '2025-06-14T09:55:34.029337'},
#  {'id': 1000,
#   'vendor': 'Dell',
#   'data': 'Invoice data for zC0O4S42PV',
#   'amount': 1071.48,
#   'category': 'Accessories',
#   'created_at': '2023-08-30T09:55:34.029337'},
#  ...]

# %%
from sqlalchemy.orm import sessionmaker

SessionLocal = sessionmaker(bind=engine)
session = SessionLocal()

session.query(Document).delete()
session.commit()
session.close()
